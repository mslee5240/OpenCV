# %% [markdown]
# # 이미지에서 글자 추출하기

# %% [markdown]
# ## **1.관련 모듈 설치**
#
# - OCR(optical character recognition) : 이미지로부터 텍스트를 인식하고, 추출하는 소프트웨어
# - Tesseract : 1984년~1994년 HP연구소에서 개발된 오픈 소스 OCR 엔진
#     - 유니코드(UTF-8)을 지원하며, 100개 이상의 언어 인식 가능
#     - PNG, JPEG, TIFF 등 다양한 이미지 포맷 지원##

# %%
# https://pypi.org/project/pytesseract/
# colab - linux
#!sudo apt install tesseract-ocr libtesseract-dev tesseract-ocr-kor

# %% [markdown]
# Windows 기준 - 설치 방법
# 1.Tesseract 다운로드 페이지에서 Windows용 설치 파일 .exe 다운로드
# → 직접 링크: https://github.com/UB-Mannheim/tesseract/wiki (한글 포함 잘 지원됨) : 'tesseract-ocr-w64-setup-5.5.0.20241111.exe (64 bit)' 다운로드
#
# 2.설치 후, 설치 경로 예시: "C:\Users\khs\AppData\Local\Programs\Tesseract-OCR\tesseract.exe"
# 3. 파이썬 코드에 경로 등록:
# import pytesseract
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
# !pip install pytesseract

# %% [markdown]
# ## **2.관련 모듈 가져오기**

# %%
import os
import pytesseract
from PIL import Image
import cv2
#from google.colab.patches import cv2_imshow

# %% [markdown]
# ## **3.지원 언어 선택 및 이미지 파일 지정**

# %%
# 사용할 파일 공유폴더에서서 다운로드하기 - '명함.png'
#!gdown 1_pyQxA2P_HYenRYVDsWefnj-L-iZ5Pjp

# %%
#@title 이미지 파일과 언어 선택
# language = "eng+kor" #@param ['None', 'kor', 'eng', 'eng+kor']
# image = "명함.jpeg" #@param {type:"string"}

# lang = None if language == "None" else language
# file_name = image

# %% [markdown]
# ## 4.이미지 읽어와 텍스트 추출하기

# %% [markdown]
# - 방법1 : cv2 사용하여 이미지 읽기

# %%
#이미지를 불러와 gray 스케일로 변환해 준다.
image = cv2.imread(file_name)

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# 전처리 후 이미지 표시
cv2_imshow(image)

# OCR 실행 - pytesseract의 image to string을 사용하여 글자를 추출한다.
text = pytesseract.image_to_string(image_gray, lang = language)
print(Text)

# %% [markdown]
# - 방법2 : PIL 사용하여 이미지 읽기

# %%
file_name = "명함.png"
language = "eng+kor"

#이미지를 불러와 gray 스케일로 변환해 준다.
image = Image.open(file_name)

# 이미지를 화면에 표시합니다.
import matplotlib.pyplot as plt
plt.imshow(image, cmap='gray')
plt.title('Input Image')
plt.axis('off')  # 축을 숨깁니다.
plt.show()

# pytesseract의 image to string을 사용하여 글자를 추출한다.
text = pytesseract.image_to_string(image, lang = language)

print(text)
# Out:
# -----------------------------------------------------------
# FileNotFoundError         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pytesseract\pytesseract.py:275, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     274 try:
# --> 275     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     276 except OSError as e:
#
# File ~\anaconda3\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
# ...

# %% [markdown]
# ## **<연습문제> 1.다른 이미지 파일을 가져와 글자를 추출해보세요**

# %%
# Code here

# %% [markdown]
# ## **<연습문제> 2.추출한 결과를 한글변환.txt 파일에 저장할 수 있도록 작성해보세요**

# %%
# Code here

# %%
import random
import time

# 학생 명단
student_name = ['강연웅', '곽명진',  '권세은' ,'김도겸', '김민지',
                '김민준2', '김우진',  '김정훈', '김희주', '나성호',
                '박준우', '손하영', '심영재', '연응찬',  '오정일',
                '유경환', '유승화', '윤태영', '윤호영', '이가영',
                '이건',   '이경빈',  '이다인', '이동욱',  '이동주',
                '이상엽', '이용석',  '이원준', '이하랑', '전상준',
                '전찬주', '정재현', '조유정', '조하율', '조헌',
                '주형준', '진세현', '최형욱' ]

# 무작위 추첨
winners = random.sample(student_name, 7)
time.sleep(3)
print("크리스마스 커피 쿠폰 당첨자:", winners)
