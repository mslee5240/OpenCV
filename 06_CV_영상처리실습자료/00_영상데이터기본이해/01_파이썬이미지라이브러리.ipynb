# %% [markdown]
# # 이미지 데이터 처리 패키지
#
# ## 1. OpenCV 패키지 : cv2
# - OpenCV(Open Source Computer Vision) : 다양한 영상 처리에 사용할 수 있는 오픈소스 라이브러리
# - cv2 패키지를 import해서 사용
# - cv2.imread():이미지나 동영상을 읽어들이는 함수 - Numpy배열을 반환
#
# ### 1) 패키지 설치하기
# - Anaconda Prompt 에서 다음 명령 실행
# ```python
# pip install opencv-python
# ```
# - 주피터노트북 셀에서 아래와 같이 명령 실행
# ```python
# !pip install opencv-python
# ```
# ### 2) 모듈 가져오기
# ```python
# import cv2
# cv2.__version__
# ```

# %%
import cv2
file_name = '../cv_images/banana.jpg'
# rgb 이미지 불러오기
rgb_image = cv2.imread(file_name)
rgb_image.shape
# Out:
# (671, 777, 3)

# %%
rgb_image[2]
# Out:
# array([[255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        ...,
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255]], dtype=uint8)

# %% [markdown]
# ## 2.파이썬 패키지 : Pillow

# %%
from PIL import Image
 
# 이미지 읽기
file_name = '../cv_images/banana.jpg'
image = Image.open(file_name)
 
# 이미지 출력 : 새 윈도우에
image.show()

# 이미지 출력 : Jupyter 셀 내부
plt.imshow(image)
plt.axis('off')  # 축 제거
plt.show()

# 이미지 저장 : Image.save(File Path, format=None)
image.save("Test.bmp",'BMP') 

# 이미지 데이터 배열로 저장하기
import numpy as np
a = np.array(image)

# 배열의 모양(shape) 확인
print("Shape:", a.shape)

a[:2]
# Out:
# Shape: (671, 777, 3)
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %% [markdown]
# ## 3.파이썬 패키지 : Scikit-Image

# %%
# skimage 사용하려면 아래 패키지 설치하기
# !pip install scikit-image

# %%
from skimage import io
import matplotlib.pyplot as plt

file_name = '../cv_images/banana.jpg'
img = io.imread(file_name)
print(img)
plt.imshow(img)
plt.show()
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[252 252 252]
#   [252 252 252]
#   [252 252 252]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[252 252 252]
#   [252 252 252]
#   [252 252 252]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[252 252 252]
#   [252 252 252]
#   [252 252 252]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
